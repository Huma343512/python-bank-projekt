# %%
# %pip install great_expectations
# %pip install pandas

import great_expectations as gx
import pandas as pd
import warnings
warnings.filterwarnings("ignore", message="`result_format` configured at the Validator-level*")

# Load the data
df = pd.read_csv("./data/transactions.csv")

# Create the ephemeral GX context
context = gx.get_context()

# Add a pandas datasource
data_source = context.data_sources.add_pandas(name="pandas")

# Add a dataframe asset
data_asset = data_source.add_dataframe_asset(name="transactions_data")

# Define the batch (entire DataFrame)
batch_definition = data_asset.add_batch_definition_whole_dataframe(name="batch_def")
batch = batch_definition.get_batch(batch_parameters={"dataframe": df})

# Create the expectation suite with a name
suite = gx.core.expectation_suite.ExpectationSuite(name="transactions_suite")

# Get the validator using the suite
validator = context.get_validator(batch=batch, expectation_suite=suite)

# Add expectations
validator.expect_column_values_to_be_between("amount", min_value=0.01, max_value=100000)

# Validate
results = validator.validate()

# Print results
print(results)
# Out:
# Requirement already satisfied: great_expectations in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (1.4.5)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (4.2.2)
# Requirement already satisfied: cryptography>=3.2 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (45.0.3)
# Requirement already satisfied: jinja2>=3 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (3.1.6)
# Requirement already satisfied: jsonschema>=2.5.1 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (4.24.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (3.26.1)
# Requirement already satisfied: mistune>=0.8.4 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (3.1.3)
# Requirement already satisfied: packaging in c:\users\susan\appdata\roaming\python\python311\site-packages (from great_expectations) (25.0)
# Requirement already satisfied: posthog<4,>3 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (3.25.0)
# Requirement already satisfied: pydantic>=1.10.7 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (2.11.5)
# Requirement already satisfied: pyparsing>=2.4 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\susan\appdata\roaming\python\python311\site-packages (from great_expectations) (2.9.0.post0)
# Requirement already satisfied: requests>=2.20 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (2.32.3)
# Requirement already satisfied: ruamel.yaml>=0.16 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (0.18.11)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (1.15.3)
# Requirement already satisfied: tqdm>=4.59.0 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\susan\appdata\roaming\python\python311\site-packages (from great_expectations) (4.13.2)
# Requirement already satisfied: tzlocal>=1.2 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (5.3.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (1.26.4)
# Requirement already satisfied: pandas<2.2,>=1.3.0 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from great_expectations) (2.1.4)
# Requirement already satisfied: entrypoints in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.4)
# Requirement already satisfied: toolz in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (1.0.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=3.2->great_expectations) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=3->great_expectations) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.25.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\susan\appdata\roaming\python\python311\site-packages (from posthog<4,>3->great_expectations) (1.17.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from posthog<4,>3->great_expectations) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from posthog<4,>3->great_expectations) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from posthog<4,>3->great_expectations) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=1.10.7->great_expectations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=1.10.7->great_expectations) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=1.10.7->great_expectations) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20->great_expectations) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20->great_expectations) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20->great_expectations) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20->great_expectations) (2025.4.26)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from ruamel.yaml>=0.16->great_expectations) (0.2.12)
# Requirement already satisfied: colorama in c:\users\susan\appdata\roaming\python\python311\site-packages (from tqdm>=4.59.0->great_expectations) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->cryptography>=3.2->great_expectations) (2.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\susan\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\susan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\susan\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Calculating Metrics: 100%|██████████| 8/8 [00:00<00:00, 219.23it/s]
# Calculating Metrics: 100%|██████████| 8/8 [00:00<00:00, 243.51it/s]
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "pandas-transactions_data",
#           "column": "amount",
#           "min_value": 0.01,
#           "max_value": 100000.0
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 100000,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "transactions_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 1,
#     "successful_expectations": 1,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.5",
#     "expectation_suite_name": "transactions_suite",
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-05-28T11:50:13.888733+02:00"
#     },
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250528T095013.610411Z",
#       "pandas_data_fingerprint": "d2ca6375fc762fd7b8aa4b0b347af3f5"
#     },
#     "active_batch_definition": {
#       "datasource_name": "pandas",
#       "data_connector_name": "fluent",
#       "data_asset_name": "transactions_data",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_time": "20250528T095013.888733Z",
#     "checkpoint_name": null
#   },
#   "id": null
# }
